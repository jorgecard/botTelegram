# %%
from functions import *

# %%
df= analysis()
df
# Out:
#          Fecha  Fecha exp        Usuario                Observaciones  \
# #
# 18         NaT 2021-08-10         nano34
# 26  2021-07-22 2021-08-22         nano54               Ganador Sorteo
# 31  2021-08-04 2021-09-04        kerlyn1
# 34  2021-08-09 2021-09-09        nano 55  Fire TV Stick, TV Box, TiVo
# 50  2021-08-29 2021-09-29         nano56              Promo Fire Lite
# ..         ...        ...            ...                          ...
# 815        NaT 2025-03-05  marthamoscoso
# 816        NaT 2025-03-06    rinamoscoso
# 6   2023-01-05 2023-02-05           nano
# 11  2023-03-17 2023-04-17      fabianDGO           Pagado 2 meses más
# 21  2023-01-05 2024-02-05       bryamDGO                    Pendiente
#
#     Días de vigencia          Cliente         Cliente0                Whpp  \
# #
# 18        -1290 days    Andrés Solano    Andrés Solano  wa.me/593989659356
# 26        -1278 days           nano54           nano54                 NaN
# ...

# %%
df.dtypes
# Out:
# Fecha                datetime64[ns]
# Fecha exp            datetime64[ns]
# Usuario                      object
# Observaciones                object
# Días de vigencia    timedelta64[ns]
# Cliente                      object
# Cliente0                     object
# Whpp                         object
# Plataforma                   object
# dtype: object

# %%
texto = por_vencer(n_days=10)
print(texto)
# Out:
# (' \n \nPaul Palomeque\n2 días\nhttps://api.whatsapp.com/send?phone=593987550696&text=Buen%20d%C3%ADa%20estimado%20usuario%20Paul%20Palomeque,%20este%20mensaje%20es%20para%20recordarle%20que%20su%20cuenta%20en%20la%20plataforma%20Magis%20tiene%202%20d%C3%ADas%20de%20vigencia.%20Agradecemos%20su%20gentil%20preferencia. \n \nadrianaabad\n3 días\nPendiente\nhttps://api.whatsapp.com/send?phone=593994250243&text=Buen%20d%C3%ADa%20estimado%20usuario%20adrianaabad,%20este%20mensaje%20es%20para%20recordarle%20que%20su%20cuenta%20en%20la%20plataforma%20Magis%20tiene%203%20d%C3%ADas%20de%20vigencia.%20Agradecemos%20su%20gentil%20preferencia. \n \nRuben Gutierres\n4 días\nhttps://api.whatsapp.com/send?phone=18154914565&text=Buen%20d%C3%ADa%20estimado%20usuario%20Ruben%20Gutierres,%20este%20mensaje%20es%20para%20recordarle%20que%20su%20cuenta%20en%20la%20plataforma%20Magis%20tiene%204%20d%C3%ADas%20de%20vigencia.%20Agradecemos%20su%20gentil%20preferencia. \n \ntayo\n5 días\nhttps://api.whatsapp.
# ...

# %%
texto=vencidos()
print(texto)

# %%
texto, df=observaciones()
print(texto)
df
